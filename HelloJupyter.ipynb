# %%
print("Hello Jupyter!!")
# Out:
# Hello Jupyter!!

# %%
your_name = "Jupyter"
def hello(name):
    print("Hello {0}!!".format(name))

hello(your_name)
# Out:
# Hello Jupyter!!

# %%
hello("notebook")
# Out:
# Hello notebook!!

# %%
import math

math.sqrt(4)
# Out:
# 2.0

# %%
math.sqrt?

# %%
your_name?

# %%
def Hello(name):
    print("Hello {0} !!".format(name))

# %%
Hello("jupyter")
# Out:
# Hello jupyter !!

# %% [raw]
# import time
#
# for i in range(10):
#     print(i)
#     time.sleep(5)

# %% [markdown]
# ＃これは見出しです。
# - 箇条書
# - なう
#
# package | version
# ------- | -------
# pandas | 0.19.2
# matplotlib | 2.0.0

# %% [markdown]
# ## 標準ライブラリの利用方法
# このNotebookではPythonの"標準ライブラリ"の利用方法を解説します。
# 標準ライブラリを利用するには、"import"文を記述します。

# %%
import math

# %% [markdown]
# "import"した"math"モジュールを利用します。

# %%
print(math.sqrt(4))
# Out:
# 2.0

# %% [markdown]
# ## 数式の表示
# このコードセルでは、次のように数式を表現できます。
#
# $$
# \begin{align}
# \sqrt{2x-1}+(3+x)^3
# \end{align}
# $$
#
# $$E = mc^2$$
#
# インラインでも右記のように$\sqrt{a^2 + b^2}$記述できます。

# %%
working_dir = %pwd
working_dir
# Out:
# '/Users/todatakuya'

# %%
# %pwd
# Out:
# '/Users/todatakuya'

# %%
# %time sum(range(10000))
# Out:
# CPU times: user 219 µs, sys: 0 ns, total: 219 µs
# Wall time: 223 µs
# 49995000

# %%
# %timeit sum(range(10000))
# Out:
# 183 µs ± 10.4 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %%timeit -n 1000 -r 3

for i in range(1000):
    i*2
# Out:
# 60.1 µs ± 4.23 µs per loop (mean ± std. dev. of 3 runs, 1000 loops each)

# %%
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 10, 0.2)
y = np.sin(x)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(x,y)
plt.show
# Out:
# <img src="data:image/png;base64,..." width="640">
# <function matplotlib.pyplot.show>
