# %%
myString <- "Hello, World!"

# %%
myString
# Out:
# [1] "Hello, World!"

# %%
data <- read.csv("https://raw.githubusercontent.com/practical-jupyter/sample-data/master/anime/anime_master.csv")
summary(data)
# Out:
#     anime_id                          name                         genre
#  Min.   :    1   Saru Kani Gassen       :    2   Comedy               : 500
#  1st Qu.: 3431   Shi Wan Ge Leng Xiaohua:    2   Music                : 297
#  Median :10526   _Summer                :    1   Kids                 : 190
#  Mean   :14056   _Summer Specials       :    1   Comedy, Slice of Life: 166
#  3rd Qu.:24438   .hack//G.U. Returner   :    1   Dementia             : 137
#  Max.   :34519   .hack//G.U. Trilogy    :    1   Fantasy, Kids        : 128
#                  (Other)                :10067   (Other)              :8657
#       type         episodes           rating          members
#  Movie  :2220   Min.   :   1.00   Min.   : 1.670   Min.   :     12
#  Music  : 485   1st Qu.:   1.00   1st Qu.: 5.890   1st Qu.:    177
#  ONA    : 591   Median :   1.00   Median : 6.610   Median :   1227
#  OVA    :1932   Mean   :  13.94   Mean   : 6.508   Mean   :  18925
# ...

# %%
type_members = aggregate(members ~ type, data, sum)
barplot(type_members$members, names = type_members$type, xlab = "type", ylab = "members")
# Out:
# plot without title
